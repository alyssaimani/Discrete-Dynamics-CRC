# %%
from mathdyn.equations import *
from datatypes.loader import get_params
from phaseportrait import PhasePortrait3D
import matplotlib.pyplot as plt

params, initial, interval = get_params("params.yaml", "eq2")
t_val = np.arange(interval.t0, interval.th, interval.h)

# lower_bound = alpha - m_2/(1+math.exp(g*b_0))
# upper_bound = gamma*k*(alpha-m_2)/(r_B+gamma*k)*(1+math.exp(g*b_0))
# print('check bound:', lower_bound, upper_bound)

H_eq, C_eq, B_eq = equilibrium(params.point, params.r_H, params.r_C, params.r_B, params.alpha, params.beta, params.gamma, params.m_1, params.m_2, params.g, params.k, params.k_B, params.b_0, initial.B_nol)
eigenvalues, re, im = find_jacobian(H_eq, C_eq, B_eq, params.r_H, params.r_C, params.r_B, params.alpha, params.beta, params.gamma, params.m_1, params.m_2, params.g, params.k, params.k_B, params.b_0)
phi_val = np.real(find_phi(eigenvalues, interval.h))
print("equilibrium point:", f"({H_eq}, {C_eq}, {B_eq})")
# Out:
# equilibrium point: (0, 0, 10)

# %%
def dF(H_n, C_n, B_n, phi = phi_val, r_H=params.r_H, r_C=params.r_C, r_B=params.r_B, alpha=params.alpha, beta=params.beta, gamma=params.gamma, m_1=params.m_1, m_2=params.m_2, g=params.g, K=params.k, K_B=params.k_B, B_0=params.b_0):
    sigmoid = (1/(1+math.exp(-g*(B_n - B_0))))
    H_new = phi * (r_H*H_n*(1-(H_n + C_n)/K) - beta*H_n*C_n - m_1*H_n*sigmoid) + H_n
    C_new = phi * (r_C*C_n*(1-(H_n + C_n)/K) + beta*H_n*C_n - alpha*C_n + m_2*C_n*sigmoid) + C_n
    B_new = phi * (r_B*B_n*(1-(B_n/K_B)) + gamma*C_n*B_n) + B_n
    return H_new, C_new, B_new


phaseportrait = PhasePortrait3D(dF, [-100,100], MeshDim=6, maxLen=2500, deltat=0.1)
phaseportrait.plot(color='viridis', grid=True)
plt.savefig('phaseportrait.jpg')
plt.show()
# Out:
# /home/adminsvr/miniconda3/envs/alyssa/lib/python3.10/site-packages/phaseportrait/streamlines/streamlines_base.py:84: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   return integrate.odeint(self._speed, coords, sign * np.arange(1,5)*0.2*deltat)[-1]
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.2920017356242D+14   r2 = -0.1441322377663D+05
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.4646862481342D+11   r2 = -0.2293694202210D+02
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.2842772946177D+14   r2 = -0.1403194488958D+05
# ...

# %%
# 2D reduction of dF: only H and B, fix C = C_eq
def dF_HB(H_n, B_n, C_fix=C_eq, phi=phi_val,
          r_H=params.r_H, r_C=params.r_C, r_B=params.r_B,
          alpha=params.alpha, beta=params.beta, gamma=params.gamma,
          m_1=params.m_1, m_2=params.m_2, g=params.g,
          K=params.k, K_B=params.k_B, B_0=params.b_0):
    
    sigmoid = 1 / (1 + math.exp(-g*(B_n - B_0)))
    
    # H update depends on C_fix
    H_new = H_n + phi * (r_H*H_n*(1-(H_n + C_fix)/K) - beta*H_n*C_fix - m_1*H_n*sigmoid)
    
    # B update depends on C_fix
    B_new = B_n + phi * (r_B*B_n*(1-(B_n/K_B)) + gamma*C_fix*B_n)
    
    return H_new, B_new

# %%
example = PhasePortrait2D(
    dF_HB,
    [[-50, 50], [-30, 30]],   # bounds for H and B
    Density=2,
    Title="H vs B"
)
example.plot()
plt.show()
# Out:
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.9110965810340D+12   r2 = -0.8456349875032D+03
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.9110965810340D+12   r2 = -0.8456349875032D+03
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.9110965810340D+12   r2 = -0.8456349875032D+03
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
#       in above,  r1 = -0.9110965810340D+12   r2 = -0.8456349875032D+03
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin   l
# ...
